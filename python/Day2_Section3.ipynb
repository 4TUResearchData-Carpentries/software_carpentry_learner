# %% [markdown]
# # Python fundamentals III

# %% [markdown]
# ## Loops

# %% [markdown]
# Let's take our previous list of odd numbers

# %%
odds = [1, 3, 5, 7]

# %% [markdown]
# We can print each item by their index, how can we print them all?

# %%
print(odds[0])
print(odds[1])
print(odds[2])
print(odds[3])
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# Works but:
#
# 1. It is not scalabe
# 2. Is difficult to mantain
# 3. Is fragile

# %%
odds = [1, 3, 5]
print(odds[0])
print(odds[1])
print(odds[2])
print(odds[3])
# Out:
# 1
# 3
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-b48c9fadc7bf> in <module>
#       3 print(odds[1])
#       4 print(odds[2])
# ----> 5 print(odds[3])
#
# IndexError: list index out of range

# %% [markdown]
# A better aproach uses a **for loop**

# %%
odds = [1, 3, 5, 7]
for num in odds:
    print(num)
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# It scales better, it's easier to maintain and is more robust

# %%
odds = [1, 3, 5, 7, 9, 11]
for num in odds:
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %% [markdown]
# What if we want to do something more with the items, not only printing?

# %%
length = 0
names = ['Curie', 'Darwin', 'Turing']
for value in names:
    length = length + 1
print('There are', length, 'names in the list.')
# Out:
# There are 3 names in the list.

# %% [markdown]
# Finding the length of an object is such a common operation that Python actually has a built-in function to do it called `len`

# %%
print(len(names))
# Out:
# 3

# %% [markdown]
# ## Conditionals

# %% [markdown]
# We can ask Python to take different actions, depending on a condition, with an `if` statement:

# %%
num = 37
if num > 100:
    print('greater')
else:
    print('not greater')
print('done')
# Out:
# not greater
# done

# %% [markdown]
# Conditional statements don’t have to include an else. If there isn’t one, Python simply does nothing if the test is false

# %%
num = 53
print('before conditional...')
if num > 100:
    print(num, 'is greater than 100')
print('...after conditional')
# Out:
# before conditional...
# ...after conditional

# %% [markdown]
# We can also chain several tests together using `elif`, which is short for “else if”

# %%
num = -3

if num > 0:
    print(num, 'is positive')
elif num == 0:
    print(num, 'is zero')
else:
    print(num, 'is negative')
# Out:
# -3 is negative

# %% [markdown]
# We can also combine tests using `and` which is only true if both parts are true:

# %%
if (1 > 0) and (-1 >= 0):
    print('both parts are true')
else:
    print('at least one part is false')
# Out:
# at least one part is false

# %% [markdown]
# while `or` is true if at least one part is true:

# %%
if (1 < 0) or (1 >= 0):
    print('at least one test is true')
# Out:
# at least one test is true
