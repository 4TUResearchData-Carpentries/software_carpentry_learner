# %% [markdown]
# # Python fundamentals

# %% [markdown]
# ## Variables

# %% [markdown]
# Any python interpreter can be used as a calculator

# %%
3 + 5 * 4
# Out:
# 23

# %%
Operations are more fun when done
