# %% [markdown]
# # Exercise: Debugging

# %% [markdown]
# ## Using the following code:

# %%
def print_message(day):
    messages = [
        'Hello, world!',
        'Today is Tuesday!',
        'It is the middle of the week.',
        'Today is Donnerstag in German!',
        'Last day of the week!',
        'Hooray for the weekend!',
        'Aw, the weekend is almost over.'
    ]
    print(messages[day])

def print_sunday_message():
    print_message(7)

print_sunday_message()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-1de20f50b5c7> in <module>
#      14     print_message(7)
#      15
# ---> 16 print_sunday_message()
#
# <ipython-input-1-1de20f50b5c7> in print_sunday_message()
#      12
#      13 def print_sunday_message():
# ---> 14     print_message(7)
#      15
#      16 print_sunday_message()
#
# <ipython-input-1-1de20f50b5c7> in print_message(day)
#       9         'Aw, the weekend is almost over.'
#      10     ]
# ---> 11     print(messages[day])
#      12
#      13 def print_sunday_message():
#
# IndexError: list index out of range

# %% [markdown]
# # Individually:
#
# 1. What is the function name where the error occurred?
# 2. On which line number in this function did the error occur?
# 3. What is the type of error?
# 4. What is the error message?

# %% [markdown]
# # In pairs
#
# 5. Fix the errors (debug)
# 6. Document your debugging steps
