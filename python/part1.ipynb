# %%
5 + 5
# Out:
# 10

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
"hello"
# Out:
# 'hello'

# %%
"hello " + "world"
# Out:
# 'hello world'

# %%
"5" + "5"
# Out:
# '55'

# %%
type(5)
# Out:
# int

# %%
type("5")
# Out:
# str

# %%
type(5.5)
# Out:
# float

# %%
age = 5

# %%
age
# Out:
# 5

# %%
type(age)
# Out:
# int

# %%
age = age + 2

# %%
age
# Out:
# 7

# %%
type(age)
# Out:
# float

# %%
age = age / 2

# %%
age
# Out:
# 3.5

# %%
type("Hello" + " world")
# Out:
# str

# %%
print(age)
# Out:
# 3.5

# %%
print("Hello" + " world")
# Out:
# Hello world

# %%
"hello" + " World"
# Out:
# 'hello World'

# %%
print(type(age))
# Out:
# <class 'float'>

# %%
print(age)
# Out:
# 3.5

# %%
str(age)
# Out:
# '3.5'

# %%
print("The age is " + str(age))
# Out:
# The age is 3.5

# %%
height_str = "180"

# %%
height_str
# Out:
# '180'

# %%
int(height_str)
# Out:
# 180

# %%
float(height_str)
# Out:
# 180.0

# %%
float("5.5")
# Out:
# 5.5

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
print("Hello", "world", "I", "am", "learning Python")
# Out:
# Hello world I am learning Python

# %%
print("Hello", "world", "I", "am", "learning Python", sep="_")
# Out:
# Hello_world_I_am_learning Python

# %%
print("Hello", "world", "I", "am", "learning Python", sep="\n")
# Out:
# Hello
# world
# I
# am
# learning Python

# %%
h, w = "Hello", "world"

# %%
h
# Out:
# 'Hello'

# %%
w
# Out:
# 'world'

# %%
# This is a comment
5 + 5
# Out:
# 10

# %%
# Now we will learn how to deal with multiple things at once

# %%
odds = [1, 3, 5, 7]

# %%
print("odds are:", odds)
# Out:
# odds are: [1, 3, 5, 7]

# %%
print ("first element:", odds[0])
print ("second element:", odds[1])
print ("last element:", odds[3])
print ("last element:", odds[-1])
# Out:
# first element: 1
# second element: 3
# last element: 7
# last element: 7

# %%
names =["Curie", "Darwing", "Turing"] #oh dear
print("Initial names:", names)
names[1] = "Darwin"
print("Final names:", names)
# Out:
# Initial names: ['Curie', 'Darwing', 'Turing']
# Final names: ['Curie', 'Darwin', 'Turing']

# %%
name = "darwin"

# %%
name
# Out:
# 'darwin'

# %%
names[0]
# Out:
# 'Curie'

# %%
name[0]
# Out:
# 'd'

# %%
name[1]
# Out:
# 'a'

# %%
name[0] = "D"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 name[0] = "D"
#
# TypeError: 'str' object does not support item assignment

# %%
names
# Out:
# ['Curie', 'Darwin', 'Turing']

# %%
veg = [['lettuce', 'lettuce', 'peppers', 'zucchini'],
     ['lettuce', 'lettuce', 'peppers', 'zucchini'],
     ['lettuce', 'cilantro', 'peppers', 'zucchini']]

# %%
veg
# Out:
# [['lettuce', 'lettuce', 'peppers', 'zucchini'],
#  ['lettuce', 'lettuce', 'peppers', 'zucchini'],
#  ['lettuce', 'cilantro', 'peppers', 'zucchini']]

# %%
veg[0]
# Out:
# ['lettuce', 'lettuce', 'peppers', 'zucchini']

# %%
veg[0][3]
# Out:
# 'zucchini'

# %%
names
# Out:
# ['Curie', 'Darwin', 'Turing']

# %%
names.append("Penrose")

# %%
names
# Out:
# ['Curie', 'Darwin', 'Turing', 'Penrose']

# %%
names.append(float(3.5))

# %%
names
# Out:
# ['Curie', 'Darwin', 'Turing', 'Penrose', 3.5]

# %%
names.remove(names[2])

# %%
names
# Out:
# ['Curie', 'Darwin', 'Penrose', 3.5]

# %%
randomnums = [1,1,1,2,2,2]

# %%
randomnums
# Out:
# [1, 1, 1, 2, 2]

# %%
randomnums.remove(2)

# %%
odds
# Out:
# [1, 3, 5, 7]

# %%
odds.append(11)

# %%
odds
# Out:
# [1, 3, 5, 7, 11]

# %%
odds[2]
# Out:
# 5

# %%
odds[1:]
# Out:
# [3, 5, 7, 11]

# %%
odds[1:4]
# Out:
# [3, 5, 7]

# %%
odds[:4]
# Out:
# [1, 3, 5, 7]

# %%
odds[-4:]
# Out:
# [3, 5, 7, 11]

# %%
odds[-4:-2]
# Out:
# [3, 5]
